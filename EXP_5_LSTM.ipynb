# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("suruchiarora/yahoo-finance-dataset-2018-2023")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'yahoo-finance-dataset-2018-2023' dataset.
# Path to dataset files: /kaggle/input/yahoo-finance-dataset-2018-2023

# %%
import pandas as pd
apple_training_complete=pd.read_excel("/content/yahoo-finance-dataset/yahoo_data.xlsx")

# %%
apple_training_processed = apple_training_complete.iloc[:, 1:2].values

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range = (0, 1))

apple_training_scaled = scaler.fit_transform(apple_training_processed)

# %%
features_set = []
labels = []
for i in range(60, 250):
    features_set.append(apple_training_scaled[i-60:i, 0])
    labels.append(apple_training_scaled[i, 0])

# %%
import numpy as np
features_set, labels = np.array(features_set), np.array(labels)

# %%
features_set = np.reshape(features_set, (features_set.shape[0], features_set.shape[1], 1))

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
model = Sequential()

# %%
model.add(LSTM(units=50, return_sequences=True, input_shape=(features_set.shape[1], 1)))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.add(Dropout(0.2))

# %%
model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(units=50, return_sequences=True))
model.add(Dropout(0.2))

model.add(LSTM(units=50))
model.add(Dropout(0.2))

# %%
model.add(Dense(units = 1))

# %%
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
model.fit(features_set, labels, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 112ms/step - loss: 0.2762
# Epoch 2/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - loss: 0.0624
# Epoch 3/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: 0.0427
# Epoch 4/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - loss: 0.0252
# Epoch 5/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 0.0151
# Epoch 6/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 186ms/step - loss: 0.0154
# Epoch 7/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 187ms/step - loss: 0.0121
# Epoch 8/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - loss: 0.0130
# Epoch 9/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: 0.0093
# Epoch 10/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 138ms/step - loss: 0.0102
# Epoch 11/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - loss: 0.0120
# Epoch 12/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 0.0098
# Epoch 13/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - loss: 0.0106
# Epoch 14/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: 0.0105
# Epoch 15/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - loss: 0.0121
# Epoch 16/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - loss: 0.0108
# Epoch 17/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 159ms/step - loss: 0.0085
# Epoch 18/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 190ms/step - loss: 0.0096
# Epoch 19/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 189ms/step - loss: 0.0096
# Epoch 20/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - loss: 0.0087
# Epoch 21/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - loss: 0.0098
# Epoch 22/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - loss: 0.0084
# Epoch 23/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 0.0094
# Epoch 24/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - loss: 0.0084
# Epoch 25/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: 0.0071
# Epoch 26/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - loss: 0.0094
# Epoch 27/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: 0.0090
# Epoch 28/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: 0.0085
# Epoch 29/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - loss: 0.0100
# Epoch 30/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 0.0097
# Epoch 31/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - loss: 0.0107
# Epoch 32/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 192ms/step - loss: 0.0095
# Epoch 33/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 190ms/step - loss: 0.0084
# Epoch 34/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - loss: 0.0083
# Epoch 35/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - loss: 0.0083
# Epoch 36/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - loss: 0.0077
# Epoch 37/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - loss: 0.0086
# Epoch 38/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - loss: 0.0092
# Epoch 39/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: 0.0074
# Epoch 40/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - loss: 0.0073
# Epoch 41/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - loss: 0.0083
# Epoch 42/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: 0.0074
# Epoch 43/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step - loss: 0.0091
# Epoch 44/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 250ms/step - loss: 0.0081
# Epoch 45/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 363ms/step - loss: 0.0072
# Epoch 46/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: 0.0095
# Epoch 47/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 0.0085
# Epoch 48/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 239ms/step - loss: 0.0085
# Epoch 49/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 169ms/step - loss: 0.0069
# Epoch 50/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - loss: 0.0083
# Epoch 51/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - loss: 0.0083
# Epoch 52/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: 0.0080
# Epoch 53/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - loss: 0.0074
# Epoch 54/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - loss: 0.0072
# Epoch 55/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 326ms/step - loss: 0.0066
# Epoch 56/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 248ms/step - loss: 0.0071
# Epoch 57/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 113ms/step - loss: 0.0071
# Epoch 58/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - loss: 0.0070
# Epoch 59/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - loss: 0.0068
# Epoch 60/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: 0.0074
# Epoch 61/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - loss: 0.0073
# Epoch 62/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 114ms/step - loss: 0.0069
# Epoch 63/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: 0.0068
# Epoch 64/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 0.0074
# Epoch 65/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 0.0068
# Epoch 66/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 184ms/step - loss: 0.0058
# Epoch 67/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 183ms/step - loss: 0.0085
# Epoch 68/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 195ms/step - loss: 0.0069
# Epoch 69/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - loss: 0.0070
# Epoch 70/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step - loss: 0.0085
# Epoch 71/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - loss: 0.0081
# Epoch 72/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - loss: 0.0078
# Epoch 73/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - loss: 0.0072
# Epoch 74/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - loss: 0.0083
# Epoch 75/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - loss: 0.0076
# Epoch 76/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 0.0071
# Epoch 77/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: 0.0064
# Epoch 78/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 0.0069
# Epoch 79/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 0.0069
# Epoch 80/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 179ms/step - loss: 0.0062
# Epoch 81/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 190ms/step - loss: 0.0060
# Epoch 82/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 246ms/step - loss: 0.0071
# Epoch 83/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 203ms/step - loss: 0.0054
# Epoch 84/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/step - loss: 0.0066
# Epoch 85/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: 0.0059
# Epoch 86/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: 0.0062
# Epoch 87/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: 0.0062
# Epoch 88/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step - loss: 0.0058
# Epoch 89/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - loss: 0.0049
# Epoch 90/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 0.0056
# Epoch 91/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 0.0058
# Epoch 92/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 0.0069
# Epoch 93/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 0.0060
# Epoch 94/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step - loss: 0.0058
# Epoch 95/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 192ms/step - loss: 0.0051
# Epoch 96/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step - loss: 0.0061
# Epoch 97/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 0.0058
# Epoch 98/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - loss: 0.0059
# Epoch 99/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - loss: 0.0055
# Epoch 100/100
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - loss: 0.0059
